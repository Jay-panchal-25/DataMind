# %%
import pandas as pd
from Backend.ml.visualization_engine import VisualizationEngine


data = {
    "salary": [25000, 30000, 40000, 35000, 45000],
    "age": [22, 25, 30, 28, 35]
}

df = pd.DataFrame(data)

viz = VisualizationEngine(df)

result = viz.generate_graph("show histogram of salary")

print(result)
# Out:
# {'chart_type': 'histogram', 'column': 'salary', 'file': 'graphs\\salary_histogram.png'}
